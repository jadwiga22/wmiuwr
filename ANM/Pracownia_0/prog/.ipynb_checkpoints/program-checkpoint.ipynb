# %% [markdown]
# # Program tworzący wykres funkcji

# %%
using Plots

# %% [markdown]
# Definiujemy funkcję $ f(x) = x^2 + 5 $.

# %%
f(x) = x^2 + 5
# Out:
# f (generic function with 1 method)

# %% [markdown]
# Tworzymy wykres funkcji $ f $ na przedziale $ [-10, 15] $.

# %%
plot( f, -10, 15)
